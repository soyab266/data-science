# %% [markdown]
# <a href="https://colab.research.google.com/github/soyab266/test/blob/master/data%20visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.figure import Figure


import plotly as py
import plotly.express as px

from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot
import cufflinks as cf
#init_notebook_mode(connected=True)
#cf.go_offline()

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.io as pio
pio.renderers.default = 'colab'
from plotly.offline import init_notebook_mode, iplot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})

# %%
df.head()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'FlightDate', 'Reporting_Airline', 'DOT_ID_Reporting_Airline',
#        'IATA_CODE_Reporting_Airline',
#        ...
#        'Div4WheelsOff', 'Div4TailNum', 'Div5Airport', 'Div5AirportID',
#        'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime',
#        'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum'],
#       dtype='object', length=110)

# %%
pd.set_option('display.max_columns', None)
df.head()

# %%
df=df.sample(n=500,random_state=None)

# %%
df.shape
# Out:
# (500, 110)

# %% [markdown]
# SCATTER PLOT

# %%
from matplotlib.figure import Figure
fig=go.Figure(data=go.Scatter(x=df['Distance'], y=df['DepTime'], mode='markers', marker=dict(color='red')))
fig.update_layout(title='Distance vs Departure Time', xaxis_title='Distance', yaxis_title='DepTime')
fig.show()

# %%
fig=go.Figure(data=go.Scatter(x=df['Distance'], y=df['DepTime'],mode='markers', marker=dict(color='green')))
fig.update_layout(title='soyab',xaxis_title='shanee', yaxis_title='ars')
fig.show()

# %% [markdown]
# LINE PLOT

# %%
df.head()

# %%
line=df.groupby('Month')['DayOfWeek'].mean().reset_index()
fig=go.Figure(data=go.Scatter( x=line['Month'], y=line['DayOfWeek'], mode='lines', marker=dict(color='red')))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head(2)
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 2672      1644306  2008        1      2          25          1  2008-02-25
# 12188      855576  2004        1      3          23          2  2004-03-23
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 2672                 XE                     20374                          XE
# 12188                DL                     19790                          DL
#
#       Tail_Number  Flight_Number_Reporting_Airline  OriginAirportID  \
# 2672       N29906                             2462            15016
# 12188      N904DE                             1171            14730
#
#        OriginAirportSeqID  OriginCityMarketID Origin  OriginCityName  \
# 2672              1501602               31123    STL   St. Louis, MO
# 12188             1473002               33044    SDF  Louisville, KY
#
#       OriginState  OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# ...

# %% [markdown]
# BAR CHART BY PX

# %% [markdown]
# Extract number of flights from a specific airline that goes to a destination

# %%
df_dest=df.groupby(['DestState'])['Flights'].sum().reset_index()
df_dest

# %%
fig=px.bar(df,x='DestState',y='Flights',title='barplot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_desti=df.groupby(['OriginState'])['Reporting_Airline'].sum().reset_index()
df_desti

# %%
fig=px.bar(df,x='Reporting_Airline', y='OriginState',title='bar')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# BUBLE CHART
# Idea: Get number of flights as per reporting airline
# Create a bubble chart using the bub_data with x-axis being reporting airline and y-axis being flights.
# Provide title to the chart
# Update size of the bubble based on the number of flights. Use size parameter.
# Update name of the hover tooltip to reporting_airline using hover_name parameter.

# %%
df_rep=df.groupby(['Reporting_Airline'])['Flights'].sum().reset_index()
df_rep

# %%
fig= px.scatter(df_rep,x='Reporting_Airline', y='Flights',title='bubble chart', size='Flights', hover_name='Reporting_Airline', size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head(2)
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 14305     1954448  2004        1      3          31          3  2004-03-31
# 21863     1623065  2012        3      7          17          2  2012-07-17
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 14305                XE                     20374                          RU
# 21863                WN                     19393                          WN
#
#       Tail_Number  Flight_Number_Reporting_Airline  OriginAirportID  \
# 14305      N12540                             2340            11042
# 21863      N260WN                             1982            13851
#
#        OriginAirportSeqID  OriginCityMarketID Origin     OriginCityName  \
# 14305             1104201               30647    CLE      Cleveland, OH
# 21863             1385103               33851    OKC  Oklahoma City, OK
#
# ...

# %%
df_org=df.groupby(['OriginCityName'])['Flights'].sum().reset_index()
df_org

# %%
fig= px.scatter(df_org, x='OriginCityName', y='Flights',size='Flights', size_max=40, title=' bubble chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# histogharm
# (Get distribution of arrival delay)
# Use px.histogram and pass the dataset.
# Pass ArrDelay to x parameter.

# %%
df['ArrDelay']=df['ArrDelay'].fillna(0)

# %%
df['ArrDelay']=df['ArrDelay'].fillna(0)
# Out:
# 0

# %%
fig=px.histogram( df['ArrDelay'],x="ArrDelay")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 14305     1954448  2004        1      3          31          3  2004-03-31
# 21863     1623065  2012        3      7          17          2  2012-07-17
# 4113      1616363  2014        3      9           5          5  2014-09-05
# 2689        26877  1997        2      5          25          7  1997-05-25
# 25517      929224  2014        2      5           7          3  2014-05-07
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 14305                XE                     20374                          RU
# 21863                WN                     19393                          WN
# 4113                 WN                     19393                          WN
# 2689                 US                     20355                          US
# 25517                WN                     19393                          WN
#
# ...

# %% [markdown]
# Pie Chart
# Learn more about pie chart here
#
# Idea: Proportion of distance group by month (month indicated by numbers)
#  Use px.pie function to create the chart. Input dataset.
# # Values parameter will set values associated to the sector. 'Month' feature is passed to it.
# # labels for the sector are passed to the `names` parameter.
# fig = px.pie(data, values='Month', names='DistanceGroup', title='Distance group proportion by month')
# fig.show()

# %%
fig=px.pie(df,title='Distance group proportion by month',values='Month',names='DistanceGroup')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.pie(df,values='Month',names='DistanceGroup',title='pie_chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.pie(df, values='Quarter',names='Month', title= 'pie_chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Sunburst Charts
# Hierarchical view in othe order of month and destination state holding value of number of flights
#
# Create sunburst chart using px.sunburst.
# Define hierarchy of sectors from root to leaves in path parameter. Here, we go from Month to DestStateName feature.
# Set sector values in values paramter. Here, we can pass in Flights feature.
# Show the figure.

# %%
fig=px.sunburst(df,path= ['Month','DestStateName'], values='Flights')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head(2)
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 14305     1954448  2004        1      3          31          3  2004-03-31
# 21863     1623065  2012        3      7          17          2  2012-07-17
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 14305                XE                     20374                          RU
# 21863                WN                     19393                          WN
#
#       Tail_Number  Flight_Number_Reporting_Airline  OriginAirportID  \
# 14305      N12540                             2340            11042
# 21863      N260WN                             1982            13851
#
#        OriginAirportSeqID  OriginCityMarketID Origin     OriginCityName  \
# 14305             1104201               30647    CLE      Cleveland, OH
# 21863             1385103               33851    OKC  Oklahoma City, OK
#
# ...

# %%
fig=px.sunburst(df,path=['Year','OriginCityName'],values='Flights')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
