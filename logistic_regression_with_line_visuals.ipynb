# %% [markdown]
# <a href="https://colab.research.google.com/github/soyab266/data-science/blob/master/logistic_regression_with_line_visuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KernelDensity

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=20)

# %%
plt.Figure(figsize=(10,8))
plt.scatter(X[:,0],X[:,1],cmap='winter',c=y )

# %%
lg=LogisticRegression()
lg.fit(X,y)
# Out:
# LogisticRegression()

# %%
print(lg.intercept_)
print(lg.coef_)
# Out:
# [3.13649441]
# [[2.36687798 0.02178765]]

# %%
m=lg.coef_[0][0]/lg.coef_[0][1]
b=lg.intercept_/lg.coef_[0][1]

# %%
x_input=np.linspace(-3,3,100)
y_input=m*x_input +b

# %%
plt.figure(figsize=(10,8))
plt.plot(x_input, y_input, color='red')
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
