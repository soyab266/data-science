# %% [markdown]
# <a href="https://colab.research.google.com/github/soyab266/data-science/blob/master/ridge_experiments_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,SGDRegressor,Ridge
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.metrics import r2_score,mean_squared_error

# %%
x, y= make_regression(  n_samples=100,n_features=1,n_informative=1,n_targets=1, noise=20, random_state=20)

# %%
plt.scatter(x,y)

# %%
lr=LinearRegression( )
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [96.23791062]
# 2.2912972569160335

# %%
r=Ridge( alpha=10)
r.fit(x,y)
print(r.coef_)
print(r.intercept_)
# Out:
# [88.54115158]
# 1.8716161631861947

# %%
r1=Ridge( alpha=100)
r1.fit(x,y)
print(r1.coef_)
print(r1.intercept_)
# Out:
# [51.48377864]
# -0.14901079666253336

# %%
plt.plot(x,y, 'bo')
plt.plot(x,lr.predict(x),color='r')
plt.plot(x,r.predict(x),color='g')
plt.plot(x,r1.predict(x), color='y')
