# %% [markdown]
# <a href="https://colab.research.google.com/github/soyab266/data-science/blob/master/BATCH_NORMALIZATION_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
import keras
#from sklearn.datasets import make_circles
from sklearn.datasets import make_moons
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv('/content/3.concertriccir2.csv')

# %%
df.head()
# Out:
#    7.003345706103683010e-01  -2.470675778972781789e-01  \
# 0                 -3.950019                   2.740080
# 1                  0.150222                  -2.157638
# 2                 -1.672050                  -0.941519
# 3                  2.560483                  -1.846577
# 4                 -1.724979                   3.463930
#
#    0.000000000000000000e+00
# 0                       1.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %%
df.columns
# Out:
# Index(['7.003345706103683010e-01', '-2.470675778972781789e-01',
#        '0.000000000000000000e+00'],
#       dtype='object')

# %%
df.rename(columns={'7.003345706103683010e-01':'X','-2.470675778972781789e-01':'Y','0.000000000000000000e+00':'class'}, inplace =True)

# %%
df.head()
# Out:
#           X         Y  class
# 0 -3.950019  2.740080    1.0
# 1  0.150222 -2.157638    1.0
# 2 -1.672050 -0.941519    1.0
# 3  2.560483 -1.846577    1.0
# 4 -1.724979  3.463930    1.0

# %%
plt.scatter(df['X'],df['Y'],c=df['class'])

# %%
X=df.iloc[:,0:2]
Y=df.iloc[:,-1]

# %%
model=Sequential()
model.add(Dense(2,activation='relu',input_dim=2))
model.add(Dense(2,activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 2)                 6
#
#  dense_4 (Dense)             (None, 2)                 6
#
#  dense_5 (Dense)             (None, 1)                 3
#
# ...
# Total params: 15 (60.00 Byte)
# Trainable params: 15 (60.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

# %%
history1=model.fit(X,Y,epochs=200, validation_split=0.3)
# Out:
# Epoch 1/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5858 - accuracy: 0.5903 - val_loss: 0.7258 - val_accuracy: 0.4333
# Epoch 2/200
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5902 - accuracy: 0.5989 - val_loss: 0.7254 - val_accuracy: 0.4333
# Epoch 3/200
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5808 - accuracy: 0.6132 - val_loss: 0.7265 - val_accuracy: 0.4333
# Epoch 4/200
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5886 - accuracy: 0.6103 - val_loss: 0.7273 - val_accuracy: 0.4333
# Epoch 5/200
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5834 - accuracy: 0.6017 - val_loss: 0.7292 - val_accuracy: 0.4333
# Epoch 6/200
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6048 - accuracy: 0.5874 - val_loss: 0.7304 - val_accuracy: 0.4333
# Epoch 7/200
# ...

# %%
from tensorflow.keras.layers import BatchNormalization
model=Sequential()
model.add(Dense(3,activation='relu',input_dim=2))
model.add(BatchNormalization())
model.add(Dense(2,activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 3)                 9
#
#  batch_normalization (Batch  (None, 3)                 12
#  Normalization)
#
#  dense_8 (Dense)             (None, 2)                 8
#
#  batch_normalization_1 (Bat  (None, 2)                 8
#  chNormalization)
#
#  dense_9 (Dense)             (None, 1)                 3
#
# ...
# Total params: 40 (160.00 Byte)
# Trainable params: 30 (120.00 Byte)
# Non-trainable params: 10 (40.00 Byte)
# _________________________________________________________________

# %%
model.compile( optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

# %%
history2=model.fit(X,Y,epochs=200, validation_split=0.3)
# Out:
# Epoch 1/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5838 - accuracy: 0.6132 - val_loss: 0.7183 - val_accuracy: 0.4600
# Epoch 2/200
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6195 - accuracy: 0.5731 - val_loss: 0.7187 - val_accuracy: 0.4600
# Epoch 3/200
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5905 - accuracy: 0.5874 - val_loss: 0.7196 - val_accuracy: 0.4733
# Epoch 4/200
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6100 - accuracy: 0.5817 - val_loss: 0.7233 - val_accuracy: 0.4733
# Epoch 5/200
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5970 - accuracy: 0.6017 - val_loss: 0.7251 - val_accuracy: 0.4600
# Epoch 6/200
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6048 - accuracy: 0.6046 - val_loss: 0.7268 - val_accuracy: 0.4600
# Epoch 7/200
# ...

# %%
plt.plot(history1.history['val_accuracy'])
plt.plot(history2.history['val_accuracy'])
