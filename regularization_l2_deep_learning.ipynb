# %% [markdown]
# <a href="https://colab.research.google.com/github/soyab266/data-science/blob/master/regularization_l2_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
import keras
#from sklearn.datasets import make_circles
from sklearn.datasets import make_moons
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

# %%
X, y = make_moons(100, noise=0.25,random_state=2)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
model=Sequential()
model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(128,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
adam=Adam(learning_rate=0.001)
model.compile( optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X,y,epochs=1000,validation_split=0.2)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.3666 - val_accuracy: 0.9500
# Epoch 2/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.3680 - val_accuracy: 0.9500
# Epoch 3/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.3720 - val_accuracy: 0.9500
# Epoch 4/1000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9500
# Epoch 5/1000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.3812 - val_accuracy: 0.9500
# Epoch 6/1000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.3816 - val_accuracy: 0.9500
# Epoch 7/1000
# ...

# %%
plot_decision_regions( X,y.astype('int'),clf=model)
# Out:
# 9600/9600 [==============================] - 8s 845us/step
# <Axes: >

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model1=Sequential()
model1.add(Dense(128,activation='relu',input_dim=2, kernel_regularizer=tensorflow.keras.regularizers.l1(0.001)))
model1.add(Dense(128,activation='relu',kernel_regularizer=tensorflow.keras.regularizers.l1(0.001)))
model1.add(Dense(1,activation='sigmoid'))

# %%
model1.compile( optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model1.fit(X,y, epochs=1000,validation_split=0.2)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 69ms/step - loss: 1.9871 - accuracy: 0.4750 - val_loss: 1.9129 - val_accuracy: 0.9000
# Epoch 2/1000
# 3/3 [==============================] - 0s 13ms/step - loss: 1.9032 - accuracy: 0.8375 - val_loss: 1.8434 - val_accuracy: 0.9000
# Epoch 3/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 1.8328 - accuracy: 0.8125 - val_loss: 1.7800 - val_accuracy: 0.9000
# Epoch 4/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 1.7679 - accuracy: 0.8125 - val_loss: 1.7194 - val_accuracy: 0.9000
# Epoch 5/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 1.7105 - accuracy: 0.8125 - val_loss: 1.6591 - val_accuracy: 0.9000
# Epoch 6/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 1.6552 - accuracy: 0.8125 - val_loss: 1.6003 - val_accuracy: 0.9000
# Epoch 7/1000
# ...

# %%
plot_decision_regions(X,y.astype('int'),clf=model1)
# Out:
# 9600/9600 [==============================] - 9s 927us/step
# <Axes: >

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model2=Sequential()
model2.add(Dense(128,activation='relu',input_dim=2, kernel_regularizer=tensorflow.keras.regularizers.l2(0.001)))
model2.add(Dense(128,activation='relu',kernel_regularizer=tensorflow.keras.regularizers.l2(0.001)))
model2.add(Dense(1,activation='sigmoid'))

# %%
adam=Adam(learning_rate=0.001)
model2.compile( optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model2.fit(X,y,epochs=1000,validation_split=0.2)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 68ms/step - loss: 0.8169 - accuracy: 0.6000 - val_loss: 0.7717 - val_accuracy: 0.9000
# Epoch 2/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7668 - accuracy: 0.8125 - val_loss: 0.7323 - val_accuracy: 0.8500
# Epoch 3/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7300 - accuracy: 0.7500 - val_loss: 0.6939 - val_accuracy: 0.8500
# Epoch 4/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6965 - accuracy: 0.7500 - val_loss: 0.6577 - val_accuracy: 0.8500
# Epoch 5/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6685 - accuracy: 0.7625 - val_loss: 0.6277 - val_accuracy: 0.8500
# Epoch 6/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6461 - accuracy: 0.7625 - val_loss: 0.5989 - val_accuracy: 0.8500
# Epoch 7/1000
# ...

# %%
plot_decision_regions(X,y.astype('int'),clf=model2)
# Out:
# 9600/9600 [==============================] - 10s 1ms/step
# <Axes: >

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model1.get_weights()[0].shape
# Out:
# (2, 128)

# %%
model1.get_weights()[0].reshape(256)

# %%
sns.boxplot(model1.get_weights()[0].reshape(256))
# Out:
# <Axes: >

# %%
sns.boxplot(model2.get_weights()[0].reshape(256))
# Out:
# <Axes: >
